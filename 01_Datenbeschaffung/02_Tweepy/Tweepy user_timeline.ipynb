# %%
# Importieren der benoetigten Bibliotheken 
import tweepy  
import pandas as pd

# %%
ACCESS_TOKEN = "1069878781110902784-H18JN2alNMGD0Uv8BFsTB1o1lEwDpS"
ACCESS_SECRET = "L21jL23ogr0qVuqJ2p8Gcjg32T3TRCMlXUWsx9x8EBHmc"
CONSUMER_KEY = "jNoyds3dIvolZmuwvKLl0lRI0"
CONSUMER_SECRET = "VZ7EawnfdNdWNx55h8qieiesjoOLBaQxE1lXs8qmFWVL0aiXJJ"

# %%
def connect_to_twitter_OAuth():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
    api = tweepy.API(auth)
    return api

# %%
api = connect_to_twitter_OAuth()

# %%
get_tweets = api.user_timeline('HSGStGallen')

tweet_list =[]
for tweet in get_tweets:
    tweet_id = tweet.id
    text = tweet.text

    tweet_list.append({'tweet_id':tweet_id, 
                'text':text})     

df = pd.DataFrame(tweet_list, columns=['tweet_id',
                                       'text'])
df.to_csv('filename.csv', index=False, sep= ';')

# %%
df
# Out:
#                tweet_id                                               text
# 0   1232929357473206273  Durch tiefe neuronale Netze sollen künftig Aut...
# 1   1232343961773182979  #Lohndiskriminierung beginnt im Kopf - ein Gas...
# 2   1231894773981700098  Das Unternehmen #Tesla polarisiert. Prof. Erwi...
# 3   1231875240919171072  Umweltthemen waren für eine Gruppe von HSG-Stu...
# 4   1231866869864374273  RT @TheCaseCentre: #CaseAwards2020 🏆\n\n🥇 Free...
# 5   1230884009300963329  #Tourismus und Reiselust: Die Nachfrage wird w...
# 6   1230768610534027264  From March 2 to March 5 2020, the second editi...
# 7   1230496008490160128  Die #Luftfahrt steht oft zuerst am öffentliche...
# 8   1230418446518751232  RT @PhilThal: Want to know what's at stake in ...
# 9   1230402039525642241  Wertschöpfungsnetzwerke sind so komplex geword...
# 10  1230140515921932289  RT @swissinfo_en: More than half of the people...
# 11  1230128868020891653  «Die Schweiz geht einige Extrameilen beim #Umw...
# 12  1230100512470687744  #ClimateChange is relevant for companies - not...
# 13  1230093462919434242  RT @UniLuzern: Smarte Produkte sind in der #Sc...
# 14  1230034834149474304  In the dossier of the new edition of HSG Focus...
# 15  1229736915106193416  HSG-Prof. @StephanBoehm diskutierte mit Gert S...
# 16  1229669674952073217  RT @taschn: Delighted to provide a socio-anthr...
# 17  1227899193475452928  HSG Geschichtsstunde: Nelly Diem war die erste...
# 18  1227854185376440321  On 28 Feb Bob Chapman @barrywehmiller will giv...
# 19  1227156125860192256  RT @rosemaryCNN: My chat with @ProfJDavis on w...
